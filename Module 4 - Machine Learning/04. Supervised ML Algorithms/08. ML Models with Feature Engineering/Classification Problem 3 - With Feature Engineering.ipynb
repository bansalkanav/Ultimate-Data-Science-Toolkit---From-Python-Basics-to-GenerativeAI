# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/data_4.csv', names=['f1', 'f2', 'y'])

df.head()
# Out:
#           f1         f2  y
# 0 -48.366669  49.000000  1
# 1 -28.764718  32.895035  1
# 2 -57.652411  30.937698  1
# 3 -60.491484  59.372470  1
# 4 -39.366669  53.000000  1

# %%
df.describe()
# Out:
#                 f1           f2            y
# count  1037.000000  1037.000000  1037.000000
# mean     -0.885901     7.191127     0.277724
# std      74.676285    69.394914     0.448093
# min    -134.736012  -134.645577     0.000000
# 25%     -62.215213   -43.120847     0.000000
# 50%       0.449238    15.000000     0.000000
# 75%      60.816617    57.000000     1.000000
# max     133.602619   134.612405     1.000000

# %% [markdown]
# ## Visualization

# %%
sns.scatterplot(data=df, x='f1', y='f2', hue='y')
# Out:
# <AxesSubplot:xlabel='f1', ylabel='f2'>

# %% [markdown]
# ## Questions
#
# - Is it possible to use Logistic Regression in the above scenerio for separating +ve's and -ve's?
#
# - Can you suggest other algorithms which are suitable for classification except for Logistic Regression?
#
# - If Logistic Regression is not a suitable choice, can you suggest some feature engineering approaches in order to make Logistic Regression work in above scenerio? i.e. Can you project the data in a higher dimensional space, such that in that new higher dimensional space, you might find a linear surface which can separate +ve's from -ve's?
