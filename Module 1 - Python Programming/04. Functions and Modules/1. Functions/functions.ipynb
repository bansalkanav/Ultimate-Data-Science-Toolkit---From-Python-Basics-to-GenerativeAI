# %% [markdown]
# ## Python Functions

# %%
# function definition

def even_odd(var):
    if var % 2 == 0:
        return "Even"
    else:
        return "Odd"

# %%
user_input = int(input("Enter a number: "))

print(even_odd(user_input))
# Out:
# Enter a number: 90
# Even

# %%
# Write a program, to muliply a number with 10 if the given number is odd

user_input = int(input("Enter a number: "))

if even_odd(user_input) == "Odd":
    print(user_input * 10)
# Out:
# Enter a number: 981
# 9810

# %% [markdown]
# ### Function Definition & Calling a Function

# %%
def myFirstFunction():
    '''This is my first function. It will print Hello World always.'''
    print('Hello World')
    
myFirstFunction()

# try to change indentation and line of the code.
# Out:
# Hello World

# %%
print(myFirstFunction.__doc__)
# Out:
# This is my first function. It will print Hello World always.

# %%
def myf():
    ''' hi
    how 
    are you?'''
    print('hello')

myf()

print(myf.__doc__)
# Out:
# hello
#  hi
#     how
#     are you?

# %%
print(divmod(5,2))
# Out:
# (2, 1)

# %%
print(divmod.__doc__)
# Out:
# Return the tuple (x//y, x%y).  Invariant: div*y + mod == x.

# %%
print(range.__doc__)
# Out:
# range(stop) -> range object
# range(start, stop[, step]) -> range object
#
# Return an object that produces a sequence of integers from start (inclusive)
# to stop (exclusive) by step.  range(i, j) produces i, i+1, i+2, ..., j-1.
# start defaults to 0, and stop is omitted!  range(4) produces 0, 1, 2, 3.
# These are exactly the valid indices for a list of 4 elements.
# When step is given, it specifies the increment (or decrement).

# %% [markdown]
# ### Function With Arguments/Parameters

# %%
# Function with arguments/parameter

def sayHello(name):
    '''This function wishes hello'''
    print('Hello', name)
    
sayHello('TFA')

print(sayHello.__doc__)
# Out:
# Hello TFA
# This function wishes hello

# %%
# Write a function to take a number and square it

def square(num):
    '''This function prints square'''
    print('The square of {} is {}'.format(num, num**2))

square(10)
square(5)
# Out:
# The square of 10 is 100
# The square of 5 is 25

# %% [markdown]
# ### Return Statement

# %%
def square(num):
    '''This function returns square'''
    return num*num

sq = square(10)
print(sq)
# Out:
# 100

# %%
def fun():
    return "Abc"
    
fun()
# Out:
# 'Abc'

# %%
print(fun())
# Out:
# Abc

# %%
print(print('abc'))
# Out:
# abc
# None

# %%
def fun():
    print('Hello')

print(fun())
# Out:
# Hello
# None

# %%
# Multiple Returns

def add_sub(a,b):
    add = a+b
    sub = a-b
    return add, sub

addition = add_sub(15,5)

print(type(addition))

# try to remove subtraction
# Out:
# <class 'tuple'>

# %% [markdown]
# ### Scope of Variables

# %%
# Global variable is accessible everywhere

a = 10
b = 20

def fun_sum():
    print(a+b)

fun_sum()

# %%
def fun():
    l = 10
    m = 20
    
print(l + m)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-abd7b904decc> in <module>
#       3     m = 20
#       4
# ----> 5 print(l + m)
#
# NameError: name 'l' is not defined

# %%
# Local Variable

def fun_sum():
    a = 1
    b = 2
    print(a+b)

fun_sum()
# Out:
# 3

# %%
def fun_sum():
    x = 1
    y = 2
    print(x+y)

def fun_mult():
    print(x*y)

print(fun_sum())
fun_mult()
# Out:
# 3
# None
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-99daf3a4d878> in <module>
#       8
#       9 print(fun_sum())
# ---> 10 fun_mult()
#
# <ipython-input-56-99daf3a4d878> in fun_mult()
#       5
#       6 def fun_mult():
# ----> 7     print(x*y)
#       8
#       9 print(fun_sum())
#
# NameError: name 'x' is not defined

# %%
a = 10
b = 20

def fun_sum():
    a = 1
    b = 2
    print(a+b)


def fun_mult():
    print(a*b)


fun_sum()
fun_mult()
# Out:
# 3
# 200

# %% [markdown]
# ### Global Variables

# %%
temp = 10

def fun():
    temp = temp + 5
    print(temp)
    
fun()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-1-b595786a2741> in <module>
#       5     print(temp)
#       6
# ----> 7 fun()
#
# <ipython-input-1-b595786a2741> in fun()
#       2
#       3 def fun():
# ----> 4     temp = temp + 5
#       5     print(temp)
#       6
#
# UnboundLocalError: local variable 'temp' referenced before assignment

# %% [markdown]
# Rules of `global` keyword:
#
# - If a variable is assigned a value anywhere within the function’s body, it’s assumed to be a local unless explicitly declared as global.
# - Variables that are only referenced inside a function are implicitly global.
# - We use global keyword to use a global variable inside a function.
# - There is no need to use global keyword outside a function.

# %%
temp = 10

def fun():
    global temp
    temp = temp + 5
    print(temp)
    
fun()
# Out:
# 15
